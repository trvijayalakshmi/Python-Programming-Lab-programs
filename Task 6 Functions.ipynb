# %% [raw]
# 1. Write a function called gcd that takes parameters a and b and returns their greatest common divisor.

# %%
def gcd(a, b):
    while b:
        a, b = b, a % b
    return a

# Test the function
result = gcd(68,4)
print("GCD is ", result)
print("GCD of 64 and 4 is:", gcd(64, 4))   # Output: 4
print("GCD of 25 and 15 is:", gcd(25, 15)) # Output: 5
# Out:
# GCD is  4
# GCD of 64 and 4 is: 4
# GCD of 25 and 15 is: 5

# %% [raw]
# 2. Write a function to Print the Fibonacci sequence using while loop.

# %%
def fibonacci_sequence(n):
    a, b = 0, 1
    count = 0
    while count < n:
        print(a, end=" ")
        a, b = b, a + b
        count += 1

# Driver code
terms = int(input("Enter the number of terms: "))
print("Fibonacci sequence:")
fibonacci_sequence(terms)
# Out:
# Enter the number of terms: 6
# Fibonacci sequence:
# 0 1 1 2 3 5

# %% [raw]
# 3. Write a function to find factorial of a number.

# %%
def factorial(n):
    fact = 1
    for i in range(1, n+1):
        fact *= i
    return fact

print("Factorial of 5 is:", factorial(5))

# %% [raw]
# 4. Write a function called palindrome that takes a string argument and returns True if it is a palindrome and False otherwise.

# %%
# function which return reverse of a string
def isPalindrome(s):
    return s == s[::-1]

s = "malayalam"
print(isPalindrome(s))
# Out:
# True

# %%
def isPalindrome(st):
    for i in range(0, int(len(st)//2)):
        if st[i] != st[len(st)-i-1]:
            return False
    return True
 
s = "malayalam"
print(isPalindrome(s))
if isPalindrome(s):
    print("The string is a palindrome")
else:
    print("The string is not a palindrome")
# Out:
# True
# The string is a palindrome

# %% [raw]
# 5. Write a function to print all prime numbers in an interval

# %%
def prime(x, y):
    for i in range(x, y):
        if i == 0 or i == 1:
            continue
        else:
            for j in range(2, int(i/2)+1):
                if i % j == 0:
                    break
            else:
                print(i,end=" ")

# Driver program
starting_range = 6
ending_range = 30
prime(starting_range, ending_range)
# Out:
# 7 11 13 17 19 23 29

# %% [raw]
# 6. Write a function to swap two numbers.

# %%
def swap(x, y): 
    temp = x; 
    x = y; 
    y = temp; 
  
# Driver code 
x = 2
y = 3
swap(x, y) 
print(x) 
print(y)
# Out:
# 2
# 3

# %% [raw]
# 7. Write a function to convert a decimal number to binary

# %%
def binary(n):
    if n > 1:
        binary(n//2)
    print(n % 2,end = '')
    
n = int(input("enter the decimal number"))
binary(n)
# Out:
# enter the decimal number22
# 10110

# %% [raw]
# 8. Program that computes harmonic sum of n

# %%
def harmonic_sum(n):
    total = 0.0
    for i in range(1, n + 1):
        total += 1 / i
    return total

# Example usage
n = int(input("Enter a number: "))
print(f"Harmonic sum of {n} = {harmonic_sum(n)}")
# Out:
# Enter a number: 6
# Harmonic sum of 6 = 2.4499999999999997

# %%
# one line using sum() and list comprehension:
n = int(input("Enter a number: "))
harmonic = sum(1/i for i in range(1, n+1))
print(harmonic)
# Out:
# Enter a number: 6
# 2.4499999999999997
